# %%
import pandas as pd

# %%
df=pd.read_csv('../data/full_dataset.csv')
df.head()
# Out:
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# ...

# %%
df.iloc[126,2]
# Out:
# '["1 c. water", "1/2 c. butter", "1 tsp. sugar", "1 c. all-purpose flour", "4 large eggs"]'

# %%
df.iloc[100,3]
# Out:
# '["Mix dry ingredients.", "Add egg, margarine and buttermilk. Stir by hand until well blended.", "Pour onto non-stick pan or griddle with a little oil added.", "Cook until bubbly and turn over."]'

# %%
df=pd.read_csv('../data/indian.csv')
df.head()
# Out:
#                                          recipe_name  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          ingredients  total_time_mins  \
# 0  1 tablespoon Red Chilli powder,3 tablespoon Gr...               45
# 1   2 teaspoon cashew - or peanuts, 1/2 Teaspoon ...               15
# 2  1 Onion - sliced,1 teaspoon White Urad Dal (Sp...               50
# 3  1/2 teaspoon Turmeric powder (Haldi),1 tablesp...               45
# 4   oil - as per use, 1 tablespoon coriander seed...               30
#
#                 cuisine                                       instructions  \
# 0                Indian  To begin making the Masala Karela Recipe,de-se...
# ...

# %%
# path to the CSV you originally loaded (update if different)
csv_path = '../data/indian.csv'

# show current columns
print("Current columns:", df.columns.tolist())

# explicit renaming map (edit target names as you prefer)
rename_map = {
    'recipe_name': 'title',
    'ingredients': 'TranslatedIngredients',
    'TotalTimeInMins': 'time',
    'cuisine': 'cuisine',
    'instructions': 'directions',
    'url': 'url',
    'cleaned_ingredients': 'ingredients',
    'image-url': 'image_url',
    'ingredient_count': 'ingredient_count'
}

# apply rename in-place
df.rename(columns=rename_map, inplace=True)

# verify
print("Renamed columns:", df.columns.tolist())

# overwrite the original CSV with updated column names
df.to_csv(csv_path, index=False)
print(f"Saved updated dataframe to: {csv_path}")
# Out:
# Current columns: ['recipe_name', 'ingredients', 'total_time_mins', 'cuisine', 'instructions', 'url', 'cleaned_ingredients', 'image_url', 'ingredient_count']
# Renamed columns: ['title', 'TranslatedIngredients', 'total_time_mins', 'cuisine', 'directions', 'url', 'ingredients', 'image_url', 'ingredient_count']
# Saved updated dataframe to: ../data/indian.csv

# %%
import pandas as pd
df = pd.read_csv('../data/indian.csv')
row = df[df['title'] == "Vegan Mango Lassi Recipe"]
if row.empty:
    row = df[df['title'].str.contains("Vegan Mango Lassi Recipe", case=False, na=False)]
print(row['directions'])
# Out:
# 1695    To begin making Vegan Mango Lassi Recipe, peel...
# Name: directions, dtype: object

# %%
df['cuisine'].value_counts()
# Out:
# cuisine
# Continental             952
# Indian                  927
# North Indian Recipes    763
# South Indian Recipes    558
# Italian Recipes         231
#                        ...
# Burmese                   1
# Shandong                  1
# Brunch                    1
# Lunch                     1
# Dessert                   1
# Name: count, Length: 82, dtype: int64
